# %% [markdown]
# ## Assignment 12

# %% [markdown]
# ### 14. Final Assignment: Hyperparameter Tuning
#
# Based on the analysis of the top performing models and time windows, your final assignment is to:
#
# 1. **Identify the top performing models and time windows:** Review the results from steps 6, 8, and 10 to determine which model types and time window sizes consistently yielded the lowest test MAE.
# 2. **Select a few promising combinations:** Choose a few combinations of the best performing models and their corresponding best performing time windows for further investigation.
# 3. **Perform hyperparameter tuning:** For each selected model and time window combination, use different techniques to find the optimal hyperparameters. Focus on a smaller set of hyperparameter values to keep the tuning process manageable.
# 4. **Train models with tuned hyperparameters:** Train the selected models on the chosen time window data using the optimized hyperparameters.
# 5. **Evaluate and compare:** Evaluate the performance of the tuned models using MAE and RMSE and compare them to the original models.
# 6. **Document your findings:** Summarize your process, results, and conclusions in a markdown cell. Explain which tuned model performed best and why.
