# %% [markdown]
# ## L8 Assignment

# %% [markdown]
# #### **Assignment: CIFAR-100 Image Classification**
#
# Your task is to apply the concepts and techniques learned in this Fashion-MNIST project to the CIFAR-100 dataset. CIFAR-100 is a dataset consisting of 60,000 32x32 color images in 100 classes, with 600 images per class. There are 50,000 training images and 10,000 test images.
#
# Follow these steps:
#
# 1.  **Dataset Setup:**
#     *   Load the CIFAR-100 dataset.
#     *   Preprocess the data (normalize pixel values, one-hot encode labels). Remember that CIFAR-100 images are 32x32 color images, so the input shape will be different from Fashion-MNIST.
#     *   Verify the shapes of the processed data.
#
# 2.  **Model Building:**
#     *   Adapt the ANN and CNN model architectures for the CIFAR-100 dataset. Consider that CIFAR-100 images are color (3 channels) and have a different resolution (32x32). You might need to adjust the input layer and potentially the number of filters or layers in the CNNs for better performance on a more complex dataset.
#
# 3.  **Model Training:**
#     *   Train the models using the preprocessed CIFAR-100 training data. Use Early Stopping and Model Checkpointing as implemented before.
#
# 4.  **Model Evaluation:**
#     *   Evaluate the trained models on the CIFAR-100 test set. Compare their performance using loss and accuracy.
#     *   Visualize training history and confusion matrices.
#
# 5.  **Prediction Analysis:**
#     *   Choose the best performing model and analyze its predictions on the CIFAR-100 test set.
#
# **Goal:** To understand how model complexity and architecture choices impact performance on a more challenging image classification dataset like CIFAR-100.

# %% [markdown]
# ### 1. Dataset Setup Documentation

# %% [markdown]
# #### 1.1) Library Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import pickle
from tensorflow import keras
import matplotlib.pyplot as plt

import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# #### 1.2) Load Dataset
#
# Load the **CIFAR-100 Image Classification** dataset from Keras, splitting it into:
# - `train_images`, `train_labels` → training set
# - `test_images`, `test_labels` → test set

# %%
def load_file(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f, encoding='bytes')
    return data

# Load Train & Test Data
train_data = load_file('data/cifar-100-python/train')
test_data = load_file('data/cifar-100-python/test')

# Extract Images & Labels
train_images = train_data[b'data']
train_labels = train_data[b'fine_labels']

test_images = test_data[b'data']
test_labels = test_data[b'fine_labels']

# %% [markdown]
# #### 1.3) Normalize Data
#
# Scale pixel values from **0–255** to the range **0–1** for faster and more stable training.
#
# **Example:**
# - Before: a pixel value could be `200`
# - After: `200 / 255 ≈ 0.78`

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# #### 1.4) Reshape Data
#
# Data is stored as:- <br>
#     RRR... GGG... BBB...

# %%
train_images = train_images.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
test_images  = test_images.reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

# %% [markdown]
# #### 1.5) One-Hot Encode Labels

# %%
train_labels_one_hot = keras.utils.to_categorical(train_labels, num_classes=100)
test_labels_one_hot = keras.utils.to_categorical(test_labels, num_classes=100)

# %% [markdown]
# #### 1.6) Verify Dataset Shapes
#
# Print the shapes of images and labels after preprocessing to confirm everything is in the expected format.
#
# **Example output:**
# - Training images shape: `(50000, 32, 32, 3)`
# - Testing images shape: `(10000, 32, 32, 3)`
# - Training labels shape: `(50000, 100)`
# - Testing labels shape: `(10000, 100)`

# %%
print("Training images shape:", train_images.shape)
print("Testing images shape:", test_images.shape)
print("Training labels shape:", train_labels_one_hot.shape)
print("Testing labels shape:", test_labels_one_hot.shape)
# Out:
# Training images shape: (50000, 32, 32, 3)
# Testing images shape: (10000, 32, 32, 3)
# Training labels shape: (50000, 100)
# Testing labels shape: (10000, 100)

# %% [markdown]
# ### 2. Model Building

# %% [markdown]
# #### 2.1) Basic ANN Model
#
# - **Flatten (32×32→1024)** → 0 params
# - **Dense (128, ReLU)** → 393,344 params
# - **Dense (64, ReLU)** →  8,256 params
# - **Dense (10, Softmax)** → 6,500 params
#
# **Total params:** 408,100

# %%
ann_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32, 3)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(100, activation='softmax')
])

ann_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

ann_model.summary()
# Out:
# c:\Users\Nabeel-IT\miniconda3\envs\tf_env\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       393,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │         6,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 408,100 (1.56 MB)
#  Trainable params: 408,100 (1.56 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 2.2) Deeper CNN Model
#
# - **Conv2D (32, 3×3) + BN + MaxPool + Dropout** → 320 + 64 params
# - **Conv2D (64, 3×3) + BN + MaxPool + Dropout** → 18,496 + 128 params
# - **Conv2D (128, 3×3) + BN + MaxPool + Dropout** → 73,856 + 256 params
# - **Flatten**
# - **Dense (128, ReLU) + BN + Dropout** → 147,584 + 256 params
# - **Dense (10, Softmax)** → 1,290 params
#
# **Total params:** ~242K

# %%
deeper_cnn_model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Conv2D(128, (3, 3), activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.5),

    keras.layers.Dense(100, activation='softmax')
])

deeper_cnn_model.compile(optimizer='adam',
                         loss='categorical_crossentropy',
                         metrics=['accuracy'])

deeper_cnn_model.summary()
# Out:
# c:\Users\Nabeel-IT\miniconda3\envs\tf_env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 100)            │        12,900 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 173,220 (676.64 KB)
#  Trainable params: 172,516 (673.89 KB)
#  Non-trainable params: 704 (2.75 KB)

# %% [markdown]
# ### 3. Train models

# %% [markdown]
# #### 3.1) Training ANN Model
#
# - **EarlyStopping**: monitors validation loss, stops if no improvement for 5 epochs, restores best weights.
# - **ModelCheckpoint**: saves best ANN weights (`best_ann_model_weights.weights.h5`) based on validation loss.
# - **Training**:
#   - Epochs: up to 30 (early stopping controls actual run)
#   - Batch size: 64
#   - Validation on test set
#   - Callbacks: EarlyStopping + ModelCheckpoint

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

model_checkpoint_ann = keras.callbacks.ModelCheckpoint(
    filepath='best_ann_model_weights.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

print("Training ANN model...")
ann_history = ann_model.fit(
    train_images,
    train_labels_one_hot,
    epochs=30,
    batch_size=60,
    validation_data=(test_images, test_labels_one_hot),
    callbacks=[early_stopping, model_checkpoint_ann]
)
print("ANN model training finished.")
# Out:
# Training ANN model...
# Epoch 1/30
# 828/834 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0353 - loss: 4.3948
# Epoch 1: val_loss improved from None to 3.96207, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.0601 - loss: 4.1842 - val_accuracy: 0.0930 - val_loss: 3.9621
# Epoch 2/30
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1057 - loss: 3.8473
# Epoch 2: val_loss improved from 3.96207 to 3.73040, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.1168 - loss: 3.7956 - val_accuracy: 0.1272 - val_loss: 3.7304
# Epoch 3/30
# 831/834 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1393 - loss: 3.6624
# Epoch 3: val_loss improved from 3.73040 to 3.64440, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.1422 - loss: 3.6482 - val_accuracy: 0.1470 - val_loss: 3.6444
# Epoch 4/30
# 827/834 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1539 - loss: 3.5764
# Epoch 4: val_loss improved from 3.64440 to 3.62047, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.1542 - loss: 3.5713 - val_accuracy: 0.1506 - val_loss: 3.6205
# Epoch 5/30
# 828/834 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1657 - loss: 3.5135
# Epoch 5: val_loss improved from 3.62047 to 3.53142, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.1650 - loss: 3.5131 - val_accuracy: 0.1658 - val_loss: 3.5314
# Epoch 6/30
# 830/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1728 - loss: 3.4672
# Epoch 6: val_loss improved from 3.53142 to 3.50606, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.1753 - loss: 3.4662 - val_accuracy: 0.1722 - val_loss: 3.5061
# Epoch 7/30
# 829/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1761 - loss: 3.4438
# Epoch 7: val_loss improved from 3.50606 to 3.49752, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.1786 - loss: 3.4317 - val_accuracy: 0.1739 - val_loss: 3.4975
# Epoch 8/30
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1890 - loss: 3.3826
# Epoch 8: val_loss improved from 3.49752 to 3.47070, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.1856 - loss: 3.3954 - val_accuracy: 0.1812 - val_loss: 3.4707
# Epoch 9/30
# 831/834 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1916 - loss: 3.3545
# Epoch 9: val_loss improved from 3.47070 to 3.45707, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1907 - loss: 3.3728 - val_accuracy: 0.1845 - val_loss: 3.4571
# Epoch 10/30
# 826/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1999 - loss: 3.3425
# Epoch 10: val_loss did not improve from 3.45707
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.1949 - loss: 3.3508 - val_accuracy: 0.1721 - val_loss: 3.4920
# Epoch 11/30
# 829/834 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2024 - loss: 3.3121
# Epoch 11: val_loss improved from 3.45707 to 3.42601, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.1984 - loss: 3.3268 - val_accuracy: 0.1890 - val_loss: 3.4260
# Epoch 12/30
# 833/834 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2047 - loss: 3.3068
# Epoch 12: val_loss did not improve from 3.42601
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.2017 - loss: 3.3131 - val_accuracy: 0.1808 - val_loss: 3.4498
# Epoch 13/30
# 827/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2044 - loss: 3.2950
# Epoch 13: val_loss improved from 3.42601 to 3.40568, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.2047 - loss: 3.2932 - val_accuracy: 0.1924 - val_loss: 3.4057
# Epoch 14/30
# 833/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2091 - loss: 3.2766
# Epoch 14: val_loss improved from 3.40568 to 3.39884, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.2075 - loss: 3.2806 - val_accuracy: 0.1895 - val_loss: 3.3988
# Epoch 15/30
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2140 - loss: 3.2487
# Epoch 15: val_loss did not improve from 3.39884
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.2101 - loss: 3.2677 - val_accuracy: 0.1912 - val_loss: 3.4234
# Epoch 16/30
# 833/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2153 - loss: 3.2427
# Epoch 16: val_loss did not improve from 3.39884
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.2148 - loss: 3.2535 - val_accuracy: 0.1852 - val_loss: 3.4271
# Epoch 17/30
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2175 - loss: 3.2273
# Epoch 17: val_loss did not improve from 3.39884
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.2133 - loss: 3.2474 - val_accuracy: 0.1916 - val_loss: 3.4032
# Epoch 18/30
# 830/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2143 - loss: 3.2359
# Epoch 18: val_loss improved from 3.39884 to 3.39041, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.2148 - loss: 3.2372 - val_accuracy: 0.1950 - val_loss: 3.3904
# Epoch 19/30
# 829/834 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2172 - loss: 3.2173
# Epoch 19: val_loss improved from 3.39041 to 3.38527, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.2143 - loss: 3.2286 - val_accuracy: 0.1964 - val_loss: 3.3853
# Epoch 20/30
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2168 - loss: 3.2151
# Epoch 20: val_loss did not improve from 3.38527
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.2155 - loss: 3.2248 - val_accuracy: 0.1950 - val_loss: 3.3904
# Epoch 21/30
# 826/834 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2183 - loss: 3.2082
# Epoch 21: val_loss did not improve from 3.38527
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.2175 - loss: 3.2154 - val_accuracy: 0.1927 - val_loss: 3.4046
# Epoch 22/30
# 831/834 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2244 - loss: 3.1927
# Epoch 22: val_loss did not improve from 3.38527
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.2221 - loss: 3.2039 - val_accuracy: 0.1936 - val_loss: 3.3924
# Epoch 23/30
# 831/834 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2209 - loss: 3.1961
# Epoch 23: val_loss improved from 3.38527 to 3.36660, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.2202 - loss: 3.2033 - val_accuracy: 0.2017 - val_loss: 3.3666
# Epoch 24/30
# 828/834 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2249 - loss: 3.1840
# Epoch 24: val_loss improved from 3.36660 to 3.36039, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2222 - loss: 3.1967 - val_accuracy: 0.2058 - val_loss: 3.3604
# Epoch 25/30
# 824/834 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2259 - loss: 3.1837
# Epoch 25: val_loss did not improve from 3.36039
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.2231 - loss: 3.1900 - val_accuracy: 0.1956 - val_loss: 3.3880
# Epoch 26/30
# 831/834 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2273 - loss: 3.1757
# Epoch 26: val_loss did not improve from 3.36039
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.2240 - loss: 3.1843 - val_accuracy: 0.1957 - val_loss: 3.4282
# Epoch 27/30
# 832/834 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2218 - loss: 3.1779
# Epoch 27: val_loss improved from 3.36039 to 3.35367, saving model to best_ann_model_weights.weights.h5
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.2238 - loss: 3.1790 - val_accuracy: 0.2056 - val_loss: 3.3537
# Epoch 28/30
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2275 - loss: 3.1595
# Epoch 28: val_loss did not improve from 3.35367
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.2267 - loss: 3.1723 - val_accuracy: 0.1962 - val_loss: 3.4075
# Epoch 29/30
# 830/834 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2328 - loss: 3.1568
# Epoch 29: val_loss did not improve from 3.35367
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2281 - loss: 3.1745 - val_accuracy: 0.2012 - val_loss: 3.3727
# Epoch 30/30
# 830/834 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2310 - loss: 3.1515
# Epoch 30: val_loss did not improve from 3.35367
# 834/834 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.2263 - loss: 3.1688 - val_accuracy: 0.1982 - val_loss: 3.3945
# ANN model training finished.

# %% [markdown]
# #### 3.2) Training Deeper CNN Model

# %%
model_checkpoint_deeper_cnn = keras.callbacks.ModelCheckpoint(
    filepath='best_deeper_cnn_model_weights.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)

print("Training Deeper CNN model...")
deeper_cnn_history = deeper_cnn_model.fit(
    train_images,
    train_labels_one_hot,
    epochs=30,
    batch_size=64,
    validation_data=(test_images, test_labels_one_hot),
    callbacks=[early_stopping, model_checkpoint_deeper_cnn]
)
print("Deeper CNN model training finished.")
# Out:
# Training Deeper CNN model...
# Epoch 1/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.0537 - loss: 4.5940
# Epoch 1: val_loss improved from None to 3.67652, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 80ms/step - accuracy: 0.0819 - loss: 4.1997 - val_accuracy: 0.1471 - val_loss: 3.6765
# Epoch 2/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.1486 - loss: 3.6219
# Epoch 2: val_loss improved from 3.67652 to 3.45493, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 84ms/step - accuracy: 0.1618 - loss: 3.5312 - val_accuracy: 0.1781 - val_loss: 3.4549
# Epoch 3/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.2020 - loss: 3.2982
# Epoch 3: val_loss improved from 3.45493 to 3.21171, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 87ms/step - accuracy: 0.2098 - loss: 3.2538 - val_accuracy: 0.2132 - val_loss: 3.2117
# Epoch 4/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2406 - loss: 3.0984
# Epoch 4: val_loss improved from 3.21171 to 2.83061, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.2462 - loss: 3.0634 - val_accuracy: 0.2972 - val_loss: 2.8306
# Epoch 5/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2605 - loss: 2.9504
# Epoch 5: val_loss did not improve from 2.83061
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 80ms/step - accuracy: 0.2635 - loss: 2.9415 - val_accuracy: 0.2245 - val_loss: 3.2614
# Epoch 6/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2851 - loss: 2.8463
# Epoch 6: val_loss improved from 2.83061 to 2.81505, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 82ms/step - accuracy: 0.2845 - loss: 2.8524 - val_accuracy: 0.2930 - val_loss: 2.8150
# Epoch 7/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2976 - loss: 2.7794
# Epoch 7: val_loss did not improve from 2.81505
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 96ms/step - accuracy: 0.2984 - loss: 2.7810 - val_accuracy: 0.2922 - val_loss: 2.8606
# Epoch 8/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3098 - loss: 2.7182
# Epoch 8: val_loss improved from 2.81505 to 2.67098, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 98ms/step - accuracy: 0.3108 - loss: 2.7274 - val_accuracy: 0.3216 - val_loss: 2.6710
# Epoch 9/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3185 - loss: 2.6741
# Epoch 9: val_loss improved from 2.67098 to 2.47959, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.3172 - loss: 2.6825 - val_accuracy: 0.3617 - val_loss: 2.4796
# Epoch 10/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3287 - loss: 2.6378
# Epoch 10: val_loss improved from 2.47959 to 2.36905, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 81ms/step - accuracy: 0.3274 - loss: 2.6409 - val_accuracy: 0.3875 - val_loss: 2.3690
# Epoch 11/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3403 - loss: 2.5973
# Epoch 11: val_loss did not improve from 2.36905
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 90ms/step - accuracy: 0.3368 - loss: 2.6059 - val_accuracy: 0.3823 - val_loss: 2.3962
# Epoch 12/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.3420 - loss: 2.5695
# Epoch 12: val_loss improved from 2.36905 to 2.27031, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 95ms/step - accuracy: 0.3412 - loss: 2.5726 - val_accuracy: 0.4097 - val_loss: 2.2703
# Epoch 13/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3495 - loss: 2.5287
# Epoch 13: val_loss improved from 2.27031 to 2.24564, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.3465 - loss: 2.5437 - val_accuracy: 0.4147 - val_loss: 2.2456
# Epoch 14/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3501 - loss: 2.5161
# Epoch 14: val_loss did not improve from 2.24564
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 92ms/step - accuracy: 0.3484 - loss: 2.5254 - val_accuracy: 0.3292 - val_loss: 2.6574
# Epoch 15/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3598 - loss: 2.4852
# Epoch 15: val_loss did not improve from 2.24564
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 71s 91ms/step - accuracy: 0.3577 - loss: 2.4964 - val_accuracy: 0.3448 - val_loss: 2.5631
# Epoch 16/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.3647 - loss: 2.4635
# Epoch 16: val_loss improved from 2.24564 to 2.23753, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 94ms/step - accuracy: 0.3619 - loss: 2.4758 - val_accuracy: 0.4179 - val_loss: 2.2375
# Epoch 17/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.3706 - loss: 2.4414
# Epoch 17: val_loss did not improve from 2.23753
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.3667 - loss: 2.4555 - val_accuracy: 0.3946 - val_loss: 2.3280
# Epoch 18/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3698 - loss: 2.4246
# Epoch 18: val_loss did not improve from 2.23753
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 79ms/step - accuracy: 0.3669 - loss: 2.4436 - val_accuracy: 0.3994 - val_loss: 2.3103
# Epoch 19/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3724 - loss: 2.4190
# Epoch 19: val_loss improved from 2.23753 to 2.22549, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 78ms/step - accuracy: 0.3703 - loss: 2.4288 - val_accuracy: 0.4165 - val_loss: 2.2255
# Epoch 20/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.3778 - loss: 2.4003
# Epoch 20: val_loss improved from 2.22549 to 2.20102, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0.3738 - loss: 2.4109 - val_accuracy: 0.4194 - val_loss: 2.2010
# Epoch 21/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3813 - loss: 2.3842
# Epoch 21: val_loss did not improve from 2.20102
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 80ms/step - accuracy: 0.3783 - loss: 2.3963 - val_accuracy: 0.4081 - val_loss: 2.2565
# Epoch 22/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3872 - loss: 2.3608
# Epoch 22: val_loss improved from 2.20102 to 2.19294, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.3807 - loss: 2.3884 - val_accuracy: 0.4305 - val_loss: 2.1929
# Epoch 23/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3828 - loss: 2.3618
# Epoch 23: val_loss did not improve from 2.19294
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 73s 93ms/step - accuracy: 0.3833 - loss: 2.3685 - val_accuracy: 0.4018 - val_loss: 2.2957
# Epoch 24/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3899 - loss: 2.3442
# Epoch 24: val_loss did not improve from 2.19294
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 76ms/step - accuracy: 0.3860 - loss: 2.3597 - val_accuracy: 0.4093 - val_loss: 2.2691
# Epoch 25/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3883 - loss: 2.3322
# Epoch 25: val_loss did not improve from 2.19294
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.3868 - loss: 2.3451 - val_accuracy: 0.4034 - val_loss: 2.3062
# Epoch 26/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3930 - loss: 2.3326
# Epoch 26: val_loss improved from 2.19294 to 2.10679, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.3910 - loss: 2.3394 - val_accuracy: 0.4437 - val_loss: 2.1068
# Epoch 27/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3895 - loss: 2.3265
# Epoch 27: val_loss improved from 2.10679 to 2.08690, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.3880 - loss: 2.3288 - val_accuracy: 0.4503 - val_loss: 2.0869
# Epoch 28/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3953 - loss: 2.2951
# Epoch 28: val_loss improved from 2.08690 to 2.02922, saving model to best_deeper_cnn_model_weights.weights.h5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.3916 - loss: 2.3218 - val_accuracy: 0.4578 - val_loss: 2.0292
# Epoch 29/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3971 - loss: 2.3006
# Epoch 29: val_loss did not improve from 2.02922
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 59s 75ms/step - accuracy: 0.3971 - loss: 2.3061 - val_accuracy: 0.4494 - val_loss: 2.0671
# Epoch 30/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3993 - loss: 2.2830
# Epoch 30: val_loss did not improve from 2.02922
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 79ms/step - accuracy: 0.3955 - loss: 2.3035 - val_accuracy: 0.4394 - val_loss: 2.1297
# Deeper CNN model training finished.

# %% [markdown]
# ### 4. Model Evaluation

# %% [markdown]
# #### 4.1) Model Evaluation Code Explanation
#
# Import utilities → Load weights (ANN, Basic CNN, Deeper CNN) → Evaluate on test set → Get loss & accuracy → Print results

# %%
ann_model.load_weights('best_ann_model_weights.weights.h5')
deeper_cnn_model.load_weights('best_deeper_cnn_model_weights.weights.h5')

loss_ann, accuracy_ann = ann_model.evaluate(test_images, test_labels_one_hot, verbose=0)
loss_deeper_cnn, accuracy_deeper_cnn = deeper_cnn_model.evaluate(test_images, test_labels_one_hot, verbose=0)


# Data
models = ['ANN', 'Deeper CNN']
losses = [loss_ann, loss_deeper_cnn]
accuracies = [accuracy_ann, accuracy_deeper_cnn]

# Dark mode style
plt.style.use("dark_background")

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Loss plot
axes[0].bar(models, losses, color='#FF6F61', edgecolor='white')
axes[0].set_title('Model Test Loss', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].grid(True, linestyle='--', alpha=0.4)

# Accuracy plot
axes[1].bar(models, accuracies, color='#6BCB77', edgecolor='white')
axes[1].set_title('Model Test Accuracy', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].grid(True, linestyle='--', alpha=0.4)

# Overall title
plt.suptitle("✨ Model Performance Comparison ✨", fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nabeel-IT\AppData\Local\Temp\ipykernel_10080\1177887749.py:33: UserWarning: Glyph 10024 (\N{SPARKLES}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\Nabeel-IT\miniconda3\envs\tf_env\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 10024 (\N{SPARKLES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### 4.2) Model Evaluation (Confusion Matrix & Report)
#
# - Predict test images (ANN, Deeper CNN)
# - Convert one-hot labels to integers
# - Get predicted labels with `argmax`
# - Print confusion matrix & classification report for each model

# %%
# Predictions
ann_predictions = ann_model.predict(test_images)
deeper_cnn_predictions = deeper_cnn_model.predict(test_images)

# Convert labels
test_labels_int = np.argmax(test_labels_one_hot, axis=1)

ann_predicted_labels = np.argmax(ann_predictions, axis=1)
deeper_cnn_predicted_labels = np.argmax(deeper_cnn_predictions, axis=1)

# Confusion matrices
cm_ann = confusion_matrix(test_labels_int, ann_predicted_labels)
cm_deeper = confusion_matrix(test_labels_int, deeper_cnn_predicted_labels)
cm_deeper = confusion_matrix(test_labels_int, deeper_cnn_predicted_labels)

# Plot side by side
fig, axes = plt.subplots(1, 2, figsize=(18, 5))

sns.heatmap(cm_ann, annot=True, fmt="d", cmap="Blues", ax=axes[0])
axes[0].set_title("ANN Model")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

sns.heatmap(cm_deeper, annot=True, fmt="d", cmap="Blues", ax=axes[1])
axes[1].set_title("Deeper CNN Model")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Actual")

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step

# %% [markdown]
# #### 4.3) Model Comparison
#
# - Created a dataframe to store **test loss** and **test accuracy** for ANN, Basic CNN, and Deeper CNN.
# - Plotted training history for each model (accuracy & loss vs. epochs).
# - Helps compare how models learn and generalize over time.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

models = {
    "ANN": ("cyan", ann_history),
    "Deeper CNN": ("yellow", deeper_cnn_history)
}

performance_data = {
    'Model': ['ANN', 'Deeper CNN'],
    'Test Loss': [loss_ann, loss_deeper_cnn],
    'Test Accuracy': [accuracy_ann, accuracy_deeper_cnn]
}

performance_df = pd.DataFrame(performance_data)

fig = make_subplots(rows=1, cols=2, subplot_titles=('Accuracy', 'Loss'))

for name, (color, history) in models.items():
    # Accuracy
    fig.add_trace(go.Scatter(y=history.history['accuracy'], mode='lines',
                             name=name, line=dict(color=color, dash='solid')), row=1, col=1)
    fig.add_trace(go.Scatter(y=history.history['val_accuracy'], mode='lines',
                             name=name, line=dict(color=color, dash='dot'), showlegend=False), row=1, col=1)

    # Loss
    fig.add_trace(go.Scatter(y=history.history['loss'], mode='lines',
                             name=name, line=dict(color=color, dash='solid')), row=1, col=2)
    fig.add_trace(go.Scatter(y=history.history['val_loss'], mode='lines',
                             name=name, line=dict(color=color, dash='dot'), showlegend=False), row=1, col=2)

fig.update_layout(
    title_text="Model Comparison: Accuracy & Loss (Train=Solid, Val=Dot)",
    height=500,
    width=1200,
    template="plotly_dark"
)

fig.show()
